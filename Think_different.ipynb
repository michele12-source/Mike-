# %% [markdown]
# <a href="https://colab.research.google.com/github/michele12-source/Mike-/blob/main/Think_different.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
codice_progetto_2 = """
import streamlit as st

st.set_page_config(page_title="Think Different", layout="centered")

st.markdown('''
<style>
    @import url('https://fonts.googleapis.com/css2?family=Inter:wght@100;400;900&display=swap');
    .stApp { background-color: #000; color: #FFF; font-family: 'Inter', sans-serif; }
    .hero-text { font-size: 70px; font-weight: 900; letter-spacing: -4px; line-height: 0.8; margin-bottom: 20px; }
    .quote { font-weight: 100; font-size: 22px; color: #86868b; font-style: italic; }
</style>
''', unsafe_allow_html=True)

st.markdown('<p class="hero-text">THINK<br>DIFFERENT.</p>', unsafe_allow_html=True)
st.markdown('<p class="quote">"Coloro che sono abbastanza folli da pensare di poter cambiare il mondo, sono coloro che lo fanno davvero."</p>', unsafe_allow_html=True)

st.divider()

tab1, tab2, tab3 = st.tabs(["L'ANIMA", "IL METODO", "L'IMPATTO"])

with tab1:
    st.write("Steve Jobs non vendeva oggetti, ma visioni. La tecnologia diventa invisibile per lasciare spazio all'esperienza umana.")
with tab2:
    st.info("Semplificazione (Jobs) + Diffusione (Gates) + Organizzazione (Google)")
with tab3:
    st.metric(label="Impatto Globale", value="8.6T $", delta="Infinity")
    st.code("print('Technology is not enough.')")
"""

with open("app_vision.py", "w") as f:
    f.write(codice_progetto_2)

    print("File 'app_vision.py' creato con successo! Scaricalo dalla cartella a sinistra.")
# Out:
# File 'app_vision.py' creato con successo! Scaricalo dalla cartella a sinistra.
